# %% [markdown]
# # Homework part I
#
# The first problem set contains basic tasks in pytorch.
#
# __Note:__ Instead of doing this part of homework, you can prove your skills otherwise:
# * A commit to pytorch or pytorch-based repos will do;
# * Fully implemented seminar assignment in tensorflow or theano will do;
# * Your own project in pytorch that is developed to a state in which a normal human can understand and appreciate what it does.

# %%
from __future__ import print_function
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import torch, torch.nn as nn
import torch.nn.functional as F
from torch.autograd import Variable
print(torch.__version__)
# Out:
# 1.0.1.post2

# %% [markdown]
# ### Task I - tensormancy
#
# ![img](https://media.giphy.com/media/3o751UMCYtSrRAFRFC/giphy.gif)
#
# When dealing with more complex stuff like neural network, it's best if you use tensors the way samurai uses his sword.
#
#
# __1.1 the cannabola__
# [_disclaimer_](https://gist.githubusercontent.com/justheuristic/e2c1fa28ca02670cabc42cacf3902796/raw/fd3d935cef63a01b85ed2790b5c11c370245cbd7/stddisclaimer.h)
#
# Let's write another function, this time in polar coordinates:
# $$\rho(\theta) = (1 + 0.9 \cdot cos (8 \cdot \theta) ) \cdot (1 + 0.1 \cdot cos(24 \cdot \theta)) \cdot (0.9 + 0.05 \cdot cos(200 \cdot \theta)) \cdot (1 + sin(\theta))$$
#
#
# Then convert it into cartesian coordinates ([howto](http://www.mathsisfun.com/polar-cartesian-coordinates.html)) and plot the results.
#
# Use torch tensors only: no lists, loops, numpy arrays, etc.

# %%
theta = torch.linspace(- np.pi, np.pi, steps=1000)

# %%
# compute rho(theta) as per formula above
rho = (1 + 0.9 * torch.cos(8 * theta)) * \
      (1 + 0.1 * torch.cos(24 * theta)) * \
      (0.9 + 0.05 * torch.cos(200 * theta)) * \
      (1 + torch.sin(theta))

# %%
#  Now convert polar (rho, theta) pairs into cartesian (x,y) to plot them.
x = rho * torch.cos(theta)
y = rho * torch.sin(theta)


plt.figure(figsize=[6,6])
plt.fill(x.numpy(), y.numpy(), color='green')
plt.grid()

# %% [markdown]
# ### Task II: the game of life
#
# Now it's time for you to make something more challenging. We'll implement Conway's [Game of Life](http://web.stanford.edu/~cdebs/GameOfLife/) in _pure pytorch_.
#
# While this is still a toy task, implementing game of life this way has one cool benefit: __you'll be able to run it on GPU! __ Indeed, what could be a better use of your gpu than simulating game of life on 1M/1M grids?
#
# ![img](https://cdn.tutsplus.com/gamedev/authors/legacy/Stephane%20Beniak/2012/09/11/Preview_Image.png)
# If you've skipped the url above out of sloth, here's the game of life:
# * You have a 2D grid of cells, where each cell is "alive"(1) or "dead"(0)
# * Any living cell that has 2 or 3 neighbors survives, else it dies [0,1 or 4+ neighbors]
# * Any cell with exactly 3 neighbors becomes alive (if it was dead)
#
# For this task, you are given a reference numpy implementation that you must convert to pytorch.
# _[numpy code inspired by: https://github.com/rougier/numpy-100]_
#
#
# __Note:__ You can find convolution in `torch.nn.functional.conv2d(Z,filters)`. Note that it has a different input format.

# %%
from scipy.signal import correlate2d 

def np_update(Z):
    # Count neighbours with convolution
    filters = np.array([[1,1,1],
                        [1,0,1],
                        [1,1,1]])
    
    N = correlate2d(Z,filters,mode='same')
    
    # Apply rules
    birth = (N==3) & (Z==0)
    survive = ((N==2) | (N==3)) & (Z==1)
    
    Z[:] = birth | survive
    return Z

# %%
from torch.nn.functional import conv2d

def torch_update(Z):
    """
    Implement an update function that does to Z exactly the same as np_update.
    :param Z: torch.FloatTensor of shape [height,width] containing 0s(dead) an 1s(alive)
    :returns: torch.FloatTensor Z after updates.
    
    You can opt to create new tensor or change Z inplace.
    """
    
    filters = torch.from_numpy(np.array([[1,1,1],
                                         [1,0,1],
                                         [1,1,1]])).type(torch.FloatTensor)
    
    N = conv2d(Z.view(1,1,Z.shape[0],Z.shape[1]), filters.view(1,1,3,3), padding=1).view(Z.shape[-2],Z.shape[-1])
    
    # Apply rules
    birth = (N==3) & (Z==0)
    survive = ((N==2) | (N==3)) & (Z==1)
    
    Z[:] = birth | survive
    return Z

# %%
#initial frame
Z_numpy = np.random.choice([0,1],p=(0.5,0.5),size=(100,100))
Z = torch.from_numpy(Z_numpy).type(torch.FloatTensor)

#your debug polygon :)
Z_new = torch_update(Z.clone())

#tests
Z_reference = np_update(Z_numpy.copy())
assert np.all(Z_new.numpy() == Z_reference), "your pytorch implementation doesn't match np_update. Look into Z and np_update(ZZ) to investigate."
print("Well done!")
# Out:
# Well done!

# %%
# %matplotlib notebook
plt.ion()

#initialize game field
Z = np.random.choice([0,1],size=(100,100))
Z = torch.from_numpy(Z).type(torch.FloatTensor)

fig = plt.figure()
ax = fig.add_subplot(111)
fig.show()

for _ in range(100):
    
    #update
    Z = torch_update(Z)
    
    #re-draw image
    ax.clear()
    ax.imshow(Z.numpy(),cmap='gray')
    fig.canvas.draw()
# Out:
# <img src="data:image/png;base64,..." width="432">
# <img src="data:image/png;base64,..." width="432">

# %%
#Some fun setups for your amusement

#parallel stripes
Z = np.arange(100)%2 + np.zeros([100,100])
#with a small imperfection
Z[48:52,50]=1

Z = torch.from_numpy(Z).type(torch.FloatTensor)

fig = plt.figure()
ax = fig.add_subplot(111)
fig.show()

for _ in range(100):
    Z = torch_update(Z)
    ax.clear()
    ax.imshow(Z.numpy(),cmap='gray')
    fig.canvas.draw()
# Out:
# <img src="data:image/png;base64,..." width="432">
# <img src="data:image/png;base64,..." width="432">

# %% [markdown]
# More fun with Game of Life: [video](https://www.youtube.com/watch?v=C2vgICfQawE)

# %% [markdown]
# ```
#
# ```
#
# ```
#
# ```
#
# ```
#
# ```
#
# ```
#
# ```
#
# ```
#
# ```
#
#
#
# ### Task III: Going deeper
# <img src="http://download.gamezone.com/uploads/image/data/1190338/article_post_width_a88.jpg" width=360>
# Your third trial is to build your first neural network [almost] from scratch and pure torch.
#
# This time you will solve yet another digit recognition problem, but at a greater scale
# * 10 different letters
# * 20k samples
#
# We want you to build a network that reaches at least 80% accuracy and has at least 2 linear layers in it. Naturally, it should be nonlinear to beat logistic regression. You can implement it with either
#
#
# With 10 classes you will need to use __Softmax__ at the top instead of sigmoid and train for __categorical crossentropy__  (see [here](https://www.kaggle.com/wiki/LogLoss)).  Write your own loss or use `torch.nn.functional.nll_loss`. Just make sure you understand what it accepts as an input.
#
# Note that you are not required to build 152-layer monsters here. A 2-layer (one hidden, one output) neural network should already give you an edge over logistic regression.
#
#
# __[bonus kudos]__
# If you've already beaten logistic regression with a two-layer net, but enthusiasm still ain't gone, you can try improving the test accuracy even further! It should be possible to reach 90% without convnets.
#
# __SPOILERS!__
# At the end of the notebook you will find a few tips and frequent errors.
# If you feel confident enogh, just start coding right away and get there ~~if~~ once you need to untangle yourself.

# %%
from notmnist import load_notmnist
X_train, y_train, X_test, y_test = load_notmnist(letters='ABCDEFGHIJ')
X_train, X_test = X_train.reshape([-1, 784]), X_test.reshape([-1, 784])
# Out:
# Parsing...
# found broken img: ./notMNIST_small/A/RGVtb2NyYXRpY2FCb2xkT2xkc3R5bGUgQm9sZC50dGY=.png [it's ok if <10 images are broken]
# found broken img: ./notMNIST_small/F/Q3Jvc3NvdmVyIEJvbGRPYmxpcXVlLnR0Zg==.png [it's ok if <10 images are broken]
# Done

# %%
np.min(y_test), np.max(y_test)
# Out:
# (0, 9)

# %%
# %matplotlib inline
plt.figure(figsize=[12,4])
for i in range(20):
    plt.subplot(2,10,i+1)
    plt.imshow(X_train[i].reshape([28,28]))
    plt.title(str(y_train[i]))

# %%
#< a whole lot of your code > 
model = nn.Sequential()
model.add_module('first_linear', nn.Linear(784, 200))
model.add_module('first_activation', nn.ReLU())
model.add_module('second_linear', nn.Linear(200, 50))
model.add_module('second_activation', nn.ReLU())
model.add_module('third_linear', nn.Linear(50, 10))
model.add_module('third_activation', nn.Softmax())

opt = torch.optim.Adam(model.parameters(), lr=1e-3)

# %%
model
# Out:
# Sequential(
#   (first_linear): Linear(in_features=784, out_features=200, bias=True)
#   (first_activation): ReLU()
#   (second_linear): Linear(in_features=200, out_features=50, bias=True)
#   (second_activation): ReLU()
#   (third_linear): Linear(in_features=50, out_features=10, bias=True)
#   (third_activation): Softmax()
# )

# %%
history = []
batch_size = 256
for i in range(10000):

    # sample 256 random images
    ix = np.random.randint(0, len(X_train), batch_size)
    x_batch = torch.tensor(X_train[ix], dtype=torch.float32)
    y_batch_np = y_train[ix]
    y_batch = torch.tensor(y_batch_np, dtype=torch.long)

    # predict probabilities
    y_predicted =  model(x_batch)

    criterion = nn.CrossEntropyLoss()
    loss = criterion(input=y_predicted, target=y_batch)
    
    # compute gradients
    loss.backward()

    # Adam step
    opt.step()

    # clear gradients
    opt.zero_grad() 

    history.append(loss.data.numpy())

    if i % 10 == 0:
        print("step #%i | mean loss = %.3f" % (i, np.mean(history[-10:])))
# Out:
# /Users/irina-rud/Library/Python/3.6/lib/python/site-packages/torch/nn/modules/container.py:92: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   input = module(input)
# step #0 | mean loss = 2.303
# step #10 | mean loss = 2.165
# step #20 | mean loss = 1.842
# step #30 | mean loss = 1.708
# step #40 | mean loss = 1.643
# step #50 | mean loss = 1.612
# step #60 | mean loss = 1.607
# step #70 | mean loss = 1.598
# step #80 | mean loss = 1.592
# step #90 | mean loss = 1.593
# step #100 | mean loss = 1.575
# step #110 | mean loss = 1.583
# step #120 | mean loss = 1.574
# step #130 | mean loss = 1.571
# step #140 | mean loss = 1.564
# step #150 | mean loss = 1.554
# step #160 | mean loss = 1.559
# step #170 | mean loss = 1.565
# step #180 | mean loss = 1.553
# step #190 | mean loss = 1.546
# step #200 | mean loss = 1.554
# step #210 | mean loss = 1.553
# step #220 | mean loss = 1.543
# step #230 | mean loss = 1.550
# step #240 | mean loss = 1.553
# step #250 | mean loss = 1.552
# step #260 | mean loss = 1.543
# step #270 | mean loss = 1.547
# step #280 | mean loss = 1.545
# step #290 | mean loss = 1.543
# step #300 | mean loss = 1.549
# step #310 | mean loss = 1.543
# step #320 | mean loss = 1.546
# step #330 | mean loss = 1.537
# step #340 | mean loss = 1.536
# step #350 | mean loss = 1.539
# step #360 | mean loss = 1.539
# step #370 | mean loss = 1.536
# step #380 | mean loss = 1.541
# step #390 | mean loss = 1.528
# step #400 | mean loss = 1.531
# step #410 | mean loss = 1.529
# step #420 | mean loss = 1.537
# step #430 | mean loss = 1.530
# step #440 | mean loss = 1.530
# step #450 | mean loss = 1.528
# step #460 | mean loss = 1.525
# step #470 | mean loss = 1.531
# step #480 | mean loss = 1.527
# step #490 | mean loss = 1.526
# step #500 | mean loss = 1.523
# step #510 | mean loss = 1.531
# step #520 | mean loss = 1.524
# step #530 | mean loss = 1.521
# step #540 | mean loss = 1.528
# step #550 | mean loss = 1.528
# step #560 | mean loss = 1.523
# step #570 | mean loss = 1.531
# step #580 | mean loss = 1.515
# step #590 | mean loss = 1.520
# step #600 | mean loss = 1.518
# step #610 | mean loss = 1.530
# step #620 | mean loss = 1.517
# step #630 | mean loss = 1.523
# step #640 | mean loss = 1.525
# step #650 | mean loss = 1.523
# step #660 | mean loss = 1.525
# step #670 | mean loss = 1.529
# step #680 | mean loss = 1.517
# step #690 | mean loss = 1.514
# step #700 | mean loss = 1.521
# step #710 | mean loss = 1.516
# step #720 | mean loss = 1.519
# step #730 | mean loss = 1.520
# step #740 | mean loss = 1.518
# step #750 | mean loss = 1.511
# step #760 | mean loss = 1.516
# step #770 | mean loss = 1.517
# step #780 | mean loss = 1.523
# step #790 | mean loss = 1.522
# step #800 | mean loss = 1.519
# step #810 | mean loss = 1.514
# step #820 | mean loss = 1.521
# step #830 | mean loss = 1.520
# step #840 | mean loss = 1.520
# step #850 | mean loss = 1.509
# step #860 | mean loss = 1.512
# step #870 | mean loss = 1.515
# step #880 | mean loss = 1.521
# step #890 | mean loss = 1.506
# step #900 | mean loss = 1.513
# step #910 | mean loss = 1.513
# step #920 | mean loss = 1.512
# step #930 | mean loss = 1.507
# step #940 | mean loss = 1.517
# step #950 | mean loss = 1.509
# step #960 | mean loss = 1.511
# step #970 | mean loss = 1.516
# step #980 | mean loss = 1.512
# step #990 | mean loss = 1.514
# step #1000 | mean loss = 1.515
# step #1010 | mean loss = 1.501
# step #1020 | mean loss = 1.512
# step #1030 | mean loss = 1.516
# step #1040 | mean loss = 1.516
# step #1050 | mean loss = 1.517
# step #1060 | mean loss = 1.509
# step #1070 | mean loss = 1.513
# step #1080 | mean loss = 1.500
# step #1090 | mean loss = 1.510
# step #1100 | mean loss = 1.515
# step #1110 | mean loss = 1.514
# step #1120 | mean loss = 1.502
# step #1130 | mean loss = 1.515
# step #1140 | mean loss = 1.507
# step #1150 | mean loss = 1.504
# step #1160 | mean loss = 1.506
# step #1170 | mean loss = 1.509
# step #1180 | mean loss = 1.506
# step #1190 | mean loss = 1.519
# step #1200 | mean loss = 1.510
# step #1210 | mean loss = 1.507
# step #1220 | mean loss = 1.506
# step #1230 | mean loss = 1.512
# step #1240 | mean loss = 1.508
# step #1250 | mean loss = 1.509
# step #1260 | mean loss = 1.510
# step #1270 | mean loss = 1.508
# step #1280 | mean loss = 1.505
# step #1290 | mean loss = 1.505
# step #1300 | mean loss = 1.506
# step #1310 | mean loss = 1.502
# step #1320 | mean loss = 1.506
# step #1330 | mean loss = 1.508
# step #1340 | mean loss = 1.504
# step #1350 | mean loss = 1.507
# step #1360 | mean loss = 1.510
# step #1370 | mean loss = 1.515
# step #1380 | mean loss = 1.510
# step #1390 | mean loss = 1.504
# step #1400 | mean loss = 1.505
# step #1410 | mean loss = 1.503
# step #1420 | mean loss = 1.505
# step #1430 | mean loss = 1.506
# step #1440 | mean loss = 1.504
# step #1450 | mean loss = 1.514
# step #1460 | mean loss = 1.505
# step #1470 | mean loss = 1.504
# step #1480 | mean loss = 1.505
# step #1490 | mean loss = 1.508
# step #1500 | mean loss = 1.501
# step #1510 | mean loss = 1.513
# step #1520 | mean loss = 1.510
# step #1530 | mean loss = 1.507
# step #1540 | mean loss = 1.508
# step #1550 | mean loss = 1.508
# step #1560 | mean loss = 1.504
# step #1570 | mean loss = 1.504
# step #1580 | mean loss = 1.500
# step #1590 | mean loss = 1.504
# step #1600 | mean loss = 1.518
# step #1610 | mean loss = 1.503
# step #1620 | mean loss = 1.505
# step #1630 | mean loss = 1.497
# step #1640 | mean loss = 1.505
# step #1650 | mean loss = 1.506
# step #1660 | mean loss = 1.501
# step #1670 | mean loss = 1.505
# step #1680 | mean loss = 1.499
# step #1690 | mean loss = 1.505
# step #1700 | mean loss = 1.501
# step #1710 | mean loss = 1.503
# step #1720 | mean loss = 1.507
# step #1730 | mean loss = 1.506
# step #1740 | mean loss = 1.500
# step #1750 | mean loss = 1.497
# step #1760 | mean loss = 1.508
# step #1770 | mean loss = 1.502
# step #1780 | mean loss = 1.506
# step #1790 | mean loss = 1.507
# step #1800 | mean loss = 1.507
# step #1810 | mean loss = 1.505
# step #1820 | mean loss = 1.500
# step #1830 | mean loss = 1.510
# step #1840 | mean loss = 1.500
# step #1850 | mean loss = 1.503
# step #1860 | mean loss = 1.502
# step #1870 | mean loss = 1.509
# step #1880 | mean loss = 1.510
# step #1890 | mean loss = 1.501
# step #1900 | mean loss = 1.511
# step #1910 | mean loss = 1.506
# step #1920 | mean loss = 1.503
# step #1930 | mean loss = 1.512
# step #1940 | mean loss = 1.500
# step #1950 | mean loss = 1.505
# step #1960 | mean loss = 1.499
# step #1970 | mean loss = 1.508
# step #1980 | mean loss = 1.493
# step #1990 | mean loss = 1.504
# step #2000 | mean loss = 1.503
# step #2010 | mean loss = 1.500
# step #2020 | mean loss = 1.502
# step #2030 | mean loss = 1.502
# step #2040 | mean loss = 1.504
# step #2050 | mean loss = 1.502
# step #2060 | mean loss = 1.505
# step #2070 | mean loss = 1.504
# step #2080 | mean loss = 1.501
# step #2090 | mean loss = 1.502
# step #2100 | mean loss = 1.506
# step #2110 | mean loss = 1.504
# step #2120 | mean loss = 1.514
# step #2130 | mean loss = 1.516
# step #2140 | mean loss = 1.504
# step #2150 | mean loss = 1.500
# step #2160 | mean loss = 1.508
# step #2170 | mean loss = 1.498
# step #2180 | mean loss = 1.502
# step #2190 | mean loss = 1.508
# step #2200 | mean loss = 1.499
# step #2210 | mean loss = 1.501
# step #2220 | mean loss = 1.498
# step #2230 | mean loss = 1.505
# step #2240 | mean loss = 1.506
# step #2250 | mean loss = 1.501
# step #2260 | mean loss = 1.494
# step #2270 | mean loss = 1.503
# step #2280 | mean loss = 1.505
# step #2290 | mean loss = 1.497
# step #2300 | mean loss = 1.505
# step #2310 | mean loss = 1.503
# step #2320 | mean loss = 1.508
# step #2330 | mean loss = 1.504
# step #2340 | mean loss = 1.506
# step #2350 | mean loss = 1.506
# step #2360 | mean loss = 1.506
# step #2370 | mean loss = 1.511
# step #2380 | mean loss = 1.503
# step #2390 | mean loss = 1.506
# step #2400 | mean loss = 1.510
# step #2410 | mean loss = 1.503
# step #2420 | mean loss = 1.511
# step #2430 | mean loss = 1.505
# step #2440 | mean loss = 1.505
# step #2450 | mean loss = 1.502
# step #2460 | mean loss = 1.499
# step #2470 | mean loss = 1.503
# step #2480 | mean loss = 1.500
# step #2490 | mean loss = 1.504
# step #2500 | mean loss = 1.502
# step #2510 | mean loss = 1.496
# step #2520 | mean loss = 1.511
# step #2530 | mean loss = 1.504
# step #2540 | mean loss = 1.503
# step #2550 | mean loss = 1.503
# step #2560 | mean loss = 1.499
# step #2570 | mean loss = 1.501
# step #2580 | mean loss = 1.500
# step #2590 | mean loss = 1.503
# step #2600 | mean loss = 1.508
# step #2610 | mean loss = 1.505
# step #2620 | mean loss = 1.495
# step #2630 | mean loss = 1.497
# step #2640 | mean loss = 1.497
# step #2650 | mean loss = 1.504
# step #2660 | mean loss = 1.493
# step #2670 | mean loss = 1.508
# step #2680 | mean loss = 1.502
# step #2690 | mean loss = 1.504
# step #2700 | mean loss = 1.506
# step #2710 | mean loss = 1.501
# step #2720 | mean loss = 1.502
# step #2730 | mean loss = 1.502
# step #2740 | mean loss = 1.498
# step #2750 | mean loss = 1.503
# step #2760 | mean loss = 1.503
# step #2770 | mean loss = 1.506
# step #2780 | mean loss = 1.506
# step #2790 | mean loss = 1.504
# step #2800 | mean loss = 1.504
# step #2810 | mean loss = 1.493
# step #2820 | mean loss = 1.501
# step #2830 | mean loss = 1.494
# step #2840 | mean loss = 1.498
# step #2850 | mean loss = 1.506
# step #2860 | mean loss = 1.508
# step #2870 | mean loss = 1.504
# step #2880 | mean loss = 1.500
# step #2890 | mean loss = 1.502
# step #2900 | mean loss = 1.501
# step #2910 | mean loss = 1.503
# step #2920 | mean loss = 1.502
# step #2930 | mean loss = 1.498
# step #2940 | mean loss = 1.504
# step #2950 | mean loss = 1.503
# step #2960 | mean loss = 1.504
# step #2970 | mean loss = 1.501
# step #2980 | mean loss = 1.509
# step #2990 | mean loss = 1.497
# step #3000 | mean loss = 1.499
# step #3010 | mean loss = 1.508
# step #3020 | mean loss = 1.498
# step #3030 | mean loss = 1.500
# step #3040 | mean loss = 1.504
# step #3050 | mean loss = 1.510
# step #3060 | mean loss = 1.502
# step #3070 | mean loss = 1.498
# step #3080 | mean loss = 1.504
# step #3090 | mean loss = 1.498
# step #3100 | mean loss = 1.501
# step #3110 | mean loss = 1.506
# step #3120 | mean loss = 1.501
# step #3130 | mean loss = 1.506
# step #3140 | mean loss = 1.500
# step #3150 | mean loss = 1.511
# step #3160 | mean loss = 1.509
# step #3170 | mean loss = 1.505
# step #3180 | mean loss = 1.502
# step #3190 | mean loss = 1.507
# step #3200 | mean loss = 1.498
# step #3210 | mean loss = 1.503
# step #3220 | mean loss = 1.501
# step #3230 | mean loss = 1.503
# step #3240 | mean loss = 1.505
# step #3250 | mean loss = 1.501
# step #3260 | mean loss = 1.502
# step #3270 | mean loss = 1.501
# step #3280 | mean loss = 1.506
# step #3290 | mean loss = 1.493
# step #3300 | mean loss = 1.501
# step #3310 | mean loss = 1.501
# step #3320 | mean loss = 1.500
# step #3330 | mean loss = 1.498
# step #3340 | mean loss = 1.497
# step #3350 | mean loss = 1.507
# step #3360 | mean loss = 1.505
# step #3370 | mean loss = 1.499
# step #3380 | mean loss = 1.505
# step #3390 | mean loss = 1.501
# step #3400 | mean loss = 1.501
# step #3410 | mean loss = 1.505
# step #3420 | mean loss = 1.499
# step #3430 | mean loss = 1.495
# step #3440 | mean loss = 1.500
# step #3450 | mean loss = 1.495
# step #3460 | mean loss = 1.495
# step #3470 | mean loss = 1.495
# step #3480 | mean loss = 1.508
# step #3490 | mean loss = 1.508
# step #3500 | mean loss = 1.504
# step #3510 | mean loss = 1.496
# step #3520 | mean loss = 1.495
# step #3530 | mean loss = 1.505
# step #3540 | mean loss = 1.497
# step #3550 | mean loss = 1.501
# step #3560 | mean loss = 1.504
# step #3570 | mean loss = 1.506
# step #3580 | mean loss = 1.500
# step #3590 | mean loss = 1.503
# step #3600 | mean loss = 1.507
# step #3610 | mean loss = 1.496
# step #3620 | mean loss = 1.497
# step #3630 | mean loss = 1.501
# step #3640 | mean loss = 1.508
# step #3650 | mean loss = 1.494
# step #3660 | mean loss = 1.505
# step #3670 | mean loss = 1.497
# step #3680 | mean loss = 1.498
# step #3690 | mean loss = 1.496
# step #3700 | mean loss = 1.500
# step #3710 | mean loss = 1.504
# step #3720 | mean loss = 1.493
# step #3730 | mean loss = 1.505
# step #3740 | mean loss = 1.503
# step #3750 | mean loss = 1.500
# step #3760 | mean loss = 1.498
# step #3770 | mean loss = 1.500
# step #3780 | mean loss = 1.500
# step #3790 | mean loss = 1.496
# step #3800 | mean loss = 1.502
# step #3810 | mean loss = 1.500
# step #3820 | mean loss = 1.502
# step #3830 | mean loss = 1.502
# step #3840 | mean loss = 1.491
# step #3850 | mean loss = 1.499
# step #3860 | mean loss = 1.506
# step #3870 | mean loss = 1.501
# step #3880 | mean loss = 1.501
# step #3890 | mean loss = 1.500
# step #3900 | mean loss = 1.501
# step #3910 | mean loss = 1.498
# step #3920 | mean loss = 1.504
# step #3930 | mean loss = 1.508
# step #3940 | mean loss = 1.501
# step #3950 | mean loss = 1.500
# step #3960 | mean loss = 1.496
# step #3970 | mean loss = 1.495
# step #3980 | mean loss = 1.495
# step #3990 | mean loss = 1.494
# step #4000 | mean loss = 1.505
# step #4010 | mean loss = 1.497
# step #4020 | mean loss = 1.502
# step #4030 | mean loss = 1.497
# step #4040 | mean loss = 1.504
# step #4050 | mean loss = 1.493
# step #4060 | mean loss = 1.499
# step #4070 | mean loss = 1.498
# step #4080 | mean loss = 1.497
# step #4090 | mean loss = 1.504
# step #4100 | mean loss = 1.501
# step #4110 | mean loss = 1.493
# step #4120 | mean loss = 1.499
# step #4130 | mean loss = 1.494
# step #4140 | mean loss = 1.498
# step #4150 | mean loss = 1.498
# step #4160 | mean loss = 1.496
# step #4170 | mean loss = 1.498
# step #4180 | mean loss = 1.497
# step #4190 | mean loss = 1.498
# step #4200 | mean loss = 1.503
# step #4210 | mean loss = 1.501
# step #4220 | mean loss = 1.495
# step #4230 | mean loss = 1.504
# step #4240 | mean loss = 1.499
# step #4250 | mean loss = 1.495
# step #4260 | mean loss = 1.502
# step #4270 | mean loss = 1.499
# step #4280 | mean loss = 1.498
# step #4290 | mean loss = 1.502
# step #4300 | mean loss = 1.504
# step #4310 | mean loss = 1.499
# step #4320 | mean loss = 1.494
# step #4330 | mean loss = 1.495
# step #4340 | mean loss = 1.502
# step #4350 | mean loss = 1.507
# step #4360 | mean loss = 1.505
# step #4370 | mean loss = 1.497
# step #4380 | mean loss = 1.502
# step #4390 | mean loss = 1.505
# step #4400 | mean loss = 1.492
# step #4410 | mean loss = 1.498
# step #4420 | mean loss = 1.495
# step #4430 | mean loss = 1.499
# step #4440 | mean loss = 1.492
# step #4450 | mean loss = 1.503
# step #4460 | mean loss = 1.500
# step #4470 | mean loss = 1.498
# step #4480 | mean loss = 1.501
# step #4490 | mean loss = 1.495
# step #4500 | mean loss = 1.502
# step #4510 | mean loss = 1.501
# step #4520 | mean loss = 1.493
# step #4530 | mean loss = 1.501
# step #4540 | mean loss = 1.501
# step #4550 | mean loss = 1.495
# step #4560 | mean loss = 1.500
# step #4570 | mean loss = 1.497
# step #4580 | mean loss = 1.497
# step #4590 | mean loss = 1.497
# step #4600 | mean loss = 1.500
# step #4610 | mean loss = 1.501
# step #4620 | mean loss = 1.499
# step #4630 | mean loss = 1.503
# step #4640 | mean loss = 1.499
# step #4650 | mean loss = 1.498
# step #4660 | mean loss = 1.496
# step #4670 | mean loss = 1.496
# step #4680 | mean loss = 1.503
# step #4690 | mean loss = 1.493
# step #4700 | mean loss = 1.507
# step #4710 | mean loss = 1.503
# step #4720 | mean loss = 1.496
# step #4730 | mean loss = 1.500
# step #4740 | mean loss = 1.501
# step #4750 | mean loss = 1.500
# step #4760 | mean loss = 1.505
# step #4770 | mean loss = 1.496
# step #4780 | mean loss = 1.496
# step #4790 | mean loss = 1.507
# step #4800 | mean loss = 1.502
# step #4810 | mean loss = 1.502
# step #4820 | mean loss = 1.498
# step #4830 | mean loss = 1.501
# step #4840 | mean loss = 1.497
# step #4850 | mean loss = 1.505
# step #4860 | mean loss = 1.498
# step #4870 | mean loss = 1.504
# step #4880 | mean loss = 1.505
# step #4890 | mean loss = 1.504
# step #4900 | mean loss = 1.504
# step #4910 | mean loss = 1.503
# step #4920 | mean loss = 1.511
# step #4930 | mean loss = 1.502
# step #4940 | mean loss = 1.505
# step #4950 | mean loss = 1.504
# step #4960 | mean loss = 1.504
# step #4970 | mean loss = 1.512
# step #4980 | mean loss = 1.503
# step #4990 | mean loss = 1.507
# step #5000 | mean loss = 1.500
# step #5010 | mean loss = 1.511
# step #5020 | mean loss = 1.506
# step #5030 | mean loss = 1.505
# step #5040 | mean loss = 1.497
# step #5050 | mean loss = 1.503
# step #5060 | mean loss = 1.506
# step #5070 | mean loss = 1.503
# step #5080 | mean loss = 1.502
# step #5090 | mean loss = 1.502
# step #5100 | mean loss = 1.505
# step #5110 | mean loss = 1.500
# step #5120 | mean loss = 1.504
# step #5130 | mean loss = 1.500
# step #5140 | mean loss = 1.494
# step #5150 | mean loss = 1.502
# step #5160 | mean loss = 1.506
# step #5170 | mean loss = 1.504
# step #5180 | mean loss = 1.507
# step #5190 | mean loss = 1.498
# step #5200 | mean loss = 1.499
# step #5210 | mean loss = 1.498
# step #5220 | mean loss = 1.507
# step #5230 | mean loss = 1.502
# step #5240 | mean loss = 1.494
# step #5250 | mean loss = 1.497
# step #5260 | mean loss = 1.499
# step #5270 | mean loss = 1.498
# step #5280 | mean loss = 1.500
# step #5290 | mean loss = 1.492
# step #5300 | mean loss = 1.502
# step #5310 | mean loss = 1.502
# step #5320 | mean loss = 1.499
# step #5330 | mean loss = 1.501
# step #5340 | mean loss = 1.501
# step #5350 | mean loss = 1.498
# step #5360 | mean loss = 1.504
# step #5370 | mean loss = 1.495
# step #5380 | mean loss = 1.501
# step #5390 | mean loss = 1.492
# step #5400 | mean loss = 1.502
# step #5410 | mean loss = 1.500
# step #5420 | mean loss = 1.498
# step #5430 | mean loss = 1.496
# step #5440 | mean loss = 1.498
# step #5450 | mean loss = 1.498
# step #5460 | mean loss = 1.504
# step #5470 | mean loss = 1.500
# step #5480 | mean loss = 1.493
# step #5490 | mean loss = 1.492
# step #5500 | mean loss = 1.495
# step #5510 | mean loss = 1.497
# step #5520 | mean loss = 1.500
# step #5530 | mean loss = 1.495
# step #5540 | mean loss = 1.495
# step #5550 | mean loss = 1.495
# step #5560 | mean loss = 1.498
# step #5570 | mean loss = 1.499
# step #5580 | mean loss = 1.497
# step #5590 | mean loss = 1.499
# step #5600 | mean loss = 1.497
# step #5610 | mean loss = 1.497
# step #5620 | mean loss = 1.495
# step #5630 | mean loss = 1.501
# step #5640 | mean loss = 1.500
# step #5650 | mean loss = 1.496
# step #5660 | mean loss = 1.503
# step #5670 | mean loss = 1.500
# step #5680 | mean loss = 1.500
# step #5690 | mean loss = 1.501
# step #5700 | mean loss = 1.499
# step #5710 | mean loss = 1.500
# step #5720 | mean loss = 1.499
# step #5730 | mean loss = 1.505
# step #5740 | mean loss = 1.496
# step #5750 | mean loss = 1.501
# step #5760 | mean loss = 1.501
# step #5770 | mean loss = 1.502
# step #5780 | mean loss = 1.502
# step #5790 | mean loss = 1.500
# step #5800 | mean loss = 1.497
# step #5810 | mean loss = 1.496
# step #5820 | mean loss = 1.498
# step #5830 | mean loss = 1.500
# step #5840 | mean loss = 1.502
# step #5850 | mean loss = 1.502
# step #5860 | mean loss = 1.500
# step #5870 | mean loss = 1.502
# step #5880 | mean loss = 1.501
# step #5890 | mean loss = 1.507
# step #5900 | mean loss = 1.498
# step #5910 | mean loss = 1.496
# step #5920 | mean loss = 1.495
# step #5930 | mean loss = 1.501
# step #5940 | mean loss = 1.495
# step #5950 | mean loss = 1.497
# step #5960 | mean loss = 1.504
# step #5970 | mean loss = 1.504
# step #5980 | mean loss = 1.500
# step #5990 | mean loss = 1.498
# step #6000 | mean loss = 1.495
# step #6010 | mean loss = 1.496
# step #6020 | mean loss = 1.493
# step #6030 | mean loss = 1.500
# step #6040 | mean loss = 1.496
# step #6050 | mean loss = 1.500
# step #6060 | mean loss = 1.505
# step #6070 | mean loss = 1.494
# step #6080 | mean loss = 1.496
# step #6090 | mean loss = 1.501
# step #6100 | mean loss = 1.489
# step #6110 | mean loss = 1.501
# step #6120 | mean loss = 1.505
# step #6130 | mean loss = 1.503
# step #6140 | mean loss = 1.498
# step #6150 | mean loss = 1.501
# step #6160 | mean loss = 1.498
# step #6170 | mean loss = 1.496
# step #6180 | mean loss = 1.500
# step #6190 | mean loss = 1.498
# step #6200 | mean loss = 1.493
# step #6210 | mean loss = 1.495
# step #6220 | mean loss = 1.497
# step #6230 | mean loss = 1.494
# step #6240 | mean loss = 1.506
# step #6250 | mean loss = 1.495
# step #6260 | mean loss = 1.506
# step #6270 | mean loss = 1.498
# step #6280 | mean loss = 1.501
# step #6290 | mean loss = 1.502
# step #6300 | mean loss = 1.499
# step #6310 | mean loss = 1.497
# step #6320 | mean loss = 1.495
# step #6330 | mean loss = 1.496
# step #6340 | mean loss = 1.498
# step #6350 | mean loss = 1.503
# step #6360 | mean loss = 1.507
# step #6370 | mean loss = 1.501
# step #6380 | mean loss = 1.497
# step #6390 | mean loss = 1.500
# step #6400 | mean loss = 1.494
# step #6410 | mean loss = 1.500
# step #6420 | mean loss = 1.499
# step #6430 | mean loss = 1.501
# step #6440 | mean loss = 1.500
# step #6450 | mean loss = 1.499
# step #6460 | mean loss = 1.499
# step #6470 | mean loss = 1.499
# step #6480 | mean loss = 1.492
# step #6490 | mean loss = 1.492
# step #6500 | mean loss = 1.495
# step #6510 | mean loss = 1.496
# step #6520 | mean loss = 1.494
# step #6530 | mean loss = 1.499
# step #6540 | mean loss = 1.500
# step #6550 | mean loss = 1.499
# step #6560 | mean loss = 1.498
# step #6570 | mean loss = 1.497
# step #6580 | mean loss = 1.495
# step #6590 | mean loss = 1.505
# step #6600 | mean loss = 1.501
# step #6610 | mean loss = 1.498
# step #6620 | mean loss = 1.493
# step #6630 | mean loss = 1.504
# step #6640 | mean loss = 1.502
# step #6650 | mean loss = 1.496
# step #6660 | mean loss = 1.500
# step #6670 | mean loss = 1.510
# step #6680 | mean loss = 1.500
# step #6690 | mean loss = 1.500
# step #6700 | mean loss = 1.509
# step #6710 | mean loss = 1.501
# step #6720 | mean loss = 1.496
# step #6730 | mean loss = 1.501
# step #6740 | mean loss = 1.500
# step #6750 | mean loss = 1.507
# step #6760 | mean loss = 1.501
# step #6770 | mean loss = 1.500
# step #6780 | mean loss = 1.492
# step #6790 | mean loss = 1.508
# step #6800 | mean loss = 1.496
# step #6810 | mean loss = 1.496
# step #6820 | mean loss = 1.503
# step #6830 | mean loss = 1.499
# step #6840 | mean loss = 1.506
# step #6850 | mean loss = 1.505
# step #6860 | mean loss = 1.497
# step #6870 | mean loss = 1.496
# step #6880 | mean loss = 1.502
# step #6890 | mean loss = 1.495
# step #6900 | mean loss = 1.499
# step #6910 | mean loss = 1.498
# step #6920 | mean loss = 1.495
# step #6930 | mean loss = 1.499
# step #6940 | mean loss = 1.498
# step #6950 | mean loss = 1.494
# step #6960 | mean loss = 1.502
# step #6970 | mean loss = 1.504
# step #6980 | mean loss = 1.498
# step #6990 | mean loss = 1.502
# step #7000 | mean loss = 1.498
# step #7010 | mean loss = 1.497
# step #7020 | mean loss = 1.492
# step #7030 | mean loss = 1.504
# step #7040 | mean loss = 1.498
# step #7050 | mean loss = 1.497
# step #7060 | mean loss = 1.501
# step #7070 | mean loss = 1.500
# step #7080 | mean loss = 1.496
# step #7090 | mean loss = 1.496
# step #7100 | mean loss = 1.500
# step #7110 | mean loss = 1.499
# step #7120 | mean loss = 1.493
# step #7130 | mean loss = 1.497
# step #7140 | mean loss = 1.497
# step #7150 | mean loss = 1.503
# step #7160 | mean loss = 1.499
# step #7170 | mean loss = 1.492
# step #7180 | mean loss = 1.497
# step #7190 | mean loss = 1.498
# step #7200 | mean loss = 1.504
# step #7210 | mean loss = 1.496
# step #7220 | mean loss = 1.502
# step #7230 | mean loss = 1.493
# step #7240 | mean loss = 1.501
# step #7250 | mean loss = 1.498
# step #7260 | mean loss = 1.501
# step #7270 | mean loss = 1.499
# step #7280 | mean loss = 1.506
# step #7290 | mean loss = 1.501
# step #7300 | mean loss = 1.495
# step #7310 | mean loss = 1.493
# step #7320 | mean loss = 1.494
# step #7330 | mean loss = 1.496
# step #7340 | mean loss = 1.502
# step #7350 | mean loss = 1.502
# step #7360 | mean loss = 1.494
# step #7370 | mean loss = 1.501
# step #7380 | mean loss = 1.496
# step #7390 | mean loss = 1.497
# step #7400 | mean loss = 1.501
# step #7410 | mean loss = 1.502
# step #7420 | mean loss = 1.497
# step #7430 | mean loss = 1.494
# step #7440 | mean loss = 1.499
# step #7450 | mean loss = 1.498
# step #7460 | mean loss = 1.498
# step #7470 | mean loss = 1.507
# step #7480 | mean loss = 1.493
# step #7490 | mean loss = 1.504
# step #7500 | mean loss = 1.496
# step #7510 | mean loss = 1.497
# step #7520 | mean loss = 1.498
# step #7530 | mean loss = 1.493
# step #7540 | mean loss = 1.495
# step #7550 | mean loss = 1.502
# step #7560 | mean loss = 1.496
# step #7570 | mean loss = 1.500
# step #7580 | mean loss = 1.500
# step #7590 | mean loss = 1.500
# step #7600 | mean loss = 1.494
# step #7610 | mean loss = 1.497
# step #7620 | mean loss = 1.497
# step #7630 | mean loss = 1.506
# step #7640 | mean loss = 1.498
# step #7650 | mean loss = 1.502
# step #7660 | mean loss = 1.497
# step #7670 | mean loss = 1.498
# step #7680 | mean loss = 1.501
# step #7690 | mean loss = 1.491
# step #7700 | mean loss = 1.491
# step #7710 | mean loss = 1.491
# step #7720 | mean loss = 1.491
# step #7730 | mean loss = 1.493
# step #7740 | mean loss = 1.505
# step #7750 | mean loss = 1.497
# step #7760 | mean loss = 1.489
# step #7770 | mean loss = 1.498
# step #7780 | mean loss = 1.500
# step #7790 | mean loss = 1.499
# step #7800 | mean loss = 1.492
# step #7810 | mean loss = 1.499
# step #7820 | mean loss = 1.494
# step #7830 | mean loss = 1.493
# step #7840 | mean loss = 1.500
# step #7850 | mean loss = 1.502
# step #7860 | mean loss = 1.499
# step #7870 | mean loss = 1.493
# step #7880 | mean loss = 1.499
# step #7890 | mean loss = 1.497
# step #7900 | mean loss = 1.495
# step #7910 | mean loss = 1.493
# step #7920 | mean loss = 1.494
# step #7930 | mean loss = 1.506
# step #7940 | mean loss = 1.492
# step #7950 | mean loss = 1.496
# step #7960 | mean loss = 1.496
# step #7970 | mean loss = 1.497
# step #7980 | mean loss = 1.495
# step #7990 | mean loss = 1.499
# step #8000 | mean loss = 1.496
# step #8010 | mean loss = 1.497
# step #8020 | mean loss = 1.494
# step #8030 | mean loss = 1.493
# step #8040 | mean loss = 1.506
# step #8050 | mean loss = 1.488
# step #8060 | mean loss = 1.488
# step #8070 | mean loss = 1.491
# step #8080 | mean loss = 1.495
# step #8090 | mean loss = 1.496
# step #8100 | mean loss = 1.502
# step #8110 | mean loss = 1.493
# step #8120 | mean loss = 1.497
# step #8130 | mean loss = 1.504
# step #8140 | mean loss = 1.501
# step #8150 | mean loss = 1.491
# step #8160 | mean loss = 1.497
# step #8170 | mean loss = 1.502
# step #8180 | mean loss = 1.498
# step #8190 | mean loss = 1.503
# step #8200 | mean loss = 1.497
# step #8210 | mean loss = 1.494
# step #8220 | mean loss = 1.495
# step #8230 | mean loss = 1.495
# step #8240 | mean loss = 1.495
# step #8250 | mean loss = 1.500
# step #8260 | mean loss = 1.499
# step #8270 | mean loss = 1.496
# step #8280 | mean loss = 1.498
# step #8290 | mean loss = 1.497
# step #8300 | mean loss = 1.503
# step #8310 | mean loss = 1.503
# step #8320 | mean loss = 1.497
# step #8330 | mean loss = 1.495
# step #8340 | mean loss = 1.503
# step #8350 | mean loss = 1.498
# step #8360 | mean loss = 1.496
# step #8370 | mean loss = 1.497
# step #8380 | mean loss = 1.500
# step #8390 | mean loss = 1.499
# step #8400 | mean loss = 1.499
# step #8410 | mean loss = 1.496
# step #8420 | mean loss = 1.499
# step #8430 | mean loss = 1.498
# step #8440 | mean loss = 1.496
# step #8450 | mean loss = 1.502
# step #8460 | mean loss = 1.499
# step #8470 | mean loss = 1.497
# step #8480 | mean loss = 1.492
# step #8490 | mean loss = 1.500
# step #8500 | mean loss = 1.502
# step #8510 | mean loss = 1.494
# step #8520 | mean loss = 1.503
# step #8530 | mean loss = 1.506
# step #8540 | mean loss = 1.495
# step #8550 | mean loss = 1.493
# step #8560 | mean loss = 1.497
# step #8570 | mean loss = 1.496
# step #8580 | mean loss = 1.501
# step #8590 | mean loss = 1.504
# step #8600 | mean loss = 1.501
# step #8610 | mean loss = 1.494
# step #8620 | mean loss = 1.497
# step #8630 | mean loss = 1.504
# step #8640 | mean loss = 1.503
# step #8650 | mean loss = 1.497
# step #8660 | mean loss = 1.502
# step #8670 | mean loss = 1.497
# step #8680 | mean loss = 1.501
# step #8690 | mean loss = 1.494
# step #8700 | mean loss = 1.491
# step #8710 | mean loss = 1.500
# step #8720 | mean loss = 1.499
# step #8730 | mean loss = 1.501
# step #8740 | mean loss = 1.494
# step #8750 | mean loss = 1.498
# step #8760 | mean loss = 1.497
# step #8770 | mean loss = 1.504
# step #8780 | mean loss = 1.497
# step #8790 | mean loss = 1.504
# step #8800 | mean loss = 1.499
# step #8810 | mean loss = 1.499
# step #8820 | mean loss = 1.501
# step #8830 | mean loss = 1.501
# step #8840 | mean loss = 1.506
# step #8850 | mean loss = 1.507
# step #8860 | mean loss = 1.502
# step #8870 | mean loss = 1.500
# step #8880 | mean loss = 1.508
# step #8890 | mean loss = 1.496
# step #8900 | mean loss = 1.504
# step #8910 | mean loss = 1.497
# step #8920 | mean loss = 1.499
# step #8930 | mean loss = 1.500
# step #8940 | mean loss = 1.496
# step #8950 | mean loss = 1.493
# step #8960 | mean loss = 1.494
# step #8970 | mean loss = 1.503
# step #8980 | mean loss = 1.497
# step #8990 | mean loss = 1.499
# step #9000 | mean loss = 1.500
# step #9010 | mean loss = 1.498
# step #9020 | mean loss = 1.498
# step #9030 | mean loss = 1.502
# step #9040 | mean loss = 1.502
# step #9050 | mean loss = 1.498
# step #9060 | mean loss = 1.495
# step #9070 | mean loss = 1.499
# step #9080 | mean loss = 1.502
# step #9090 | mean loss = 1.500
# step #9100 | mean loss = 1.498
# step #9110 | mean loss = 1.499
# step #9120 | mean loss = 1.494
# step #9130 | mean loss = 1.498
# step #9140 | mean loss = 1.495
# step #9150 | mean loss = 1.496
# step #9160 | mean loss = 1.494
# step #9170 | mean loss = 1.502
# step #9180 | mean loss = 1.499
# step #9190 | mean loss = 1.504
# step #9200 | mean loss = 1.496
# step #9210 | mean loss = 1.500
# step #9220 | mean loss = 1.497
# step #9230 | mean loss = 1.495
# step #9240 | mean loss = 1.501
# step #9250 | mean loss = 1.492
# step #9260 | mean loss = 1.498
# step #9270 | mean loss = 1.499
# step #9280 | mean loss = 1.498
# step #9290 | mean loss = 1.501
# step #9300 | mean loss = 1.501
# step #9310 | mean loss = 1.494
# step #9320 | mean loss = 1.498
# step #9330 | mean loss = 1.499
# step #9340 | mean loss = 1.493
# step #9350 | mean loss = 1.496
# step #9360 | mean loss = 1.496
# step #9370 | mean loss = 1.500
# step #9380 | mean loss = 1.497
# step #9390 | mean loss = 1.494
# step #9400 | mean loss = 1.496
# step #9410 | mean loss = 1.497
# step #9420 | mean loss = 1.500
# step #9430 | mean loss = 1.497
# step #9440 | mean loss = 1.497
# step #9450 | mean loss = 1.496
# step #9460 | mean loss = 1.507
# step #9470 | mean loss = 1.492
# step #9480 | mean loss = 1.492
# step #9490 | mean loss = 1.498
# step #9500 | mean loss = 1.497
# step #9510 | mean loss = 1.494
# step #9520 | mean loss = 1.494
# step #9530 | mean loss = 1.495
# step #9540 | mean loss = 1.500
# step #9550 | mean loss = 1.502
# step #9560 | mean loss = 1.501
# step #9570 | mean loss = 1.498
# step #9580 | mean loss = 1.499
# step #9590 | mean loss = 1.503
# step #9600 | mean loss = 1.498
# step #9610 | mean loss = 1.497
# step #9620 | mean loss = 1.500
# step #9630 | mean loss = 1.498
# step #9640 | mean loss = 1.500
# step #9650 | mean loss = 1.495
# step #9660 | mean loss = 1.502
# step #9670 | mean loss = 1.492
# step #9680 | mean loss = 1.502
# step #9690 | mean loss = 1.507
# step #9700 | mean loss = 1.498
# step #9710 | mean loss = 1.497
# step #9720 | mean loss = 1.493
# step #9730 | mean loss = 1.499
# step #9740 | mean loss = 1.499
# step #9750 | mean loss = 1.502
# step #9760 | mean loss = 1.497
# step #9770 | mean loss = 1.496
# step #9780 | mean loss = 1.494
# step #9790 | mean loss = 1.500
# step #9800 | mean loss = 1.499
# step #9810 | mean loss = 1.501
# step #9820 | mean loss = 1.494
# step #9830 | mean loss = 1.492
# step #9840 | mean loss = 1.492
# step #9850 | mean loss = 1.498
# step #9860 | mean loss = 1.495
# step #9870 | mean loss = 1.496
# step #9880 | mean loss = 1.493
# step #9890 | mean loss = 1.501
# step #9900 | mean loss = 1.501
# step #9910 | mean loss = 1.498
# step #9920 | mean loss = 1.505
# step #9930 | mean loss = 1.496
# step #9940 | mean loss = 1.495
# step #9950 | mean loss = 1.496
# step #9960 | mean loss = 1.496
# step #9970 | mean loss = 1.495
# step #9980 | mean loss = 1.497
# step #9990 | mean loss = 1.501

# %%
X_test_t = torch.tensor(X_test, dtype=torch.float32)
predicted_y_test_t =  model(X_test_t)
predicted_y_test_prob =(predicted_y_test_t).detach().numpy()
# Out:
# /Users/irina-rud/Library/Python/3.6/lib/python/site-packages/torch/nn/modules/container.py:92: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   input = module(input)

# %%
predicted_y_test = np.argmax(predicted_y_test_prob,  axis=1)

# %%
accuracy = np.mean(predicted_y_test == y_test)

print("Test accuracy: %.5f" % accuracy)
# Out:
# Test accuracy: 0.91968

# %% [markdown]
# ```
#
# ```
#
# ```
#
# ```
#
# ```
#
# ```
#
# ```
#
# ```
#
# ```
#
# ```
#
# ```
#
# ```
#
# ```
#
# ```
#
# ```
#
# ```
#
# ```
#
# ```
#
# ```
#
# ```
#
# ```
#
# ```
#
# ```
#
# ```
#
# ```
#
# ```
#
# ```
#
# ```
#
# ```
#
# ```
#
#
# # SPOILERS!
#
# Recommended pipeline
#
# * Adapt logistic regression from week2 seminar assignment to classify one letter against others (e.g. A vs the rest)
# * Generalize it to multiclass logistic regression.
#   - Either try to remember lecture 0 or google it.
#   - Instead of weight vector you'll have to use matrix (feature_id x class_id)
#   - softmax (exp over sum of exps) can implemented manually or as nn.Softmax (layer) F.softmax (function)
#   - probably better to use STOCHASTIC gradient descent (minibatch) for greater speed
#     - you can also try momentum/rmsprop/adawhatever
#     - in which case sample should probably be shuffled (or use random subsamples on each iteration)
# * Add a hidden layer. Now your logistic regression uses hidden neurons instead of inputs.
#   - Hidden layer uses the same math as output layer (ex-logistic regression), but uses some nonlinearity (e.g. sigmoid) instead of softmax
#   - You need to train both layers, not just output layer :)
#   - __Do not initialize weights with zeros__ (due to symmetry effects). A gaussian noize with small variance will do.
#   - 50 hidden neurons and a sigmoid nonlinearity will do for a start. Many ways to improve.
#   - In ideal casae this totals to 2 .dot's, 1 softmax and 1 sigmoid
#   - __make sure this neural network works better than logistic regression__
#
# * Now's the time to try improving the network. Consider layers (size, neuron count),  nonlinearities, optimization methods, initialization - whatever you want, but please avoid convolutions for now.
#
# * If anything seems wrong, try going through one step of training and printing everything you compute.
# * If you see NaNs midway through optimization, you can estimate log P(y|x) as via F.log_softmax(layer_before_softmax)
